# %% [markdown]
# ## **Analysis of KMeans**
# Jonathan Jones
#
# 22.05.19

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## **Customer Segmentation**:
#
# Use KMeans to create various customer segments.
#
# Use an Elbow Plot of inertia
#
# And a plot of Silhouette Scores
#
# Choose a K based on the results.

# %%
from google.colab import drive
drive.mount('/content/drive')

data = '/content/drive/MyDrive/Colab Notebooks/Week 8/cust_seg (1).csv'

df = pd.read_csv(data)

df.head()
# Out:
# Mounted at /content/drive
#    Unnamed: 0  Customer Id  Age  Edu  Years Employed  Income  Card Debt  \
# 0           0            1   41    2               6      19      0.124
# 1           1            2   47    1              26     100      4.582
# 2           2            3   33    2              10      57      6.111
# 3           3            4   29    2               4      19      0.681
# 4           4            5   47    1              31     253      9.308
#
#    Other Debt  Defaulted  DebtIncomeRatio
# 0       1.073        0.0              6.3
# 1       8.218        0.0             12.8
# 2       5.802        1.0             20.9
# 3       0.516        0.0              6.3
# 4       8.908        0.0              7.2

# %%
# Preliminary datatype check:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       850 non-null    int64
#  1   Customer Id      850 non-null    int64
#  2   Age              850 non-null    int64
#  3   Edu              850 non-null    int64
#  4   Years Employed   850 non-null    int64
#  5   Income           850 non-null    int64
#  6   Card Debt        850 non-null    float64
#  7   Other Debt       850 non-null    float64
#  8   Defaulted        700 non-null    float64
#  9   DebtIncomeRatio  850 non-null    float64
# dtypes: float64(4), int64(6)
# memory usage: 66.5 KB

# %%
# Cbeck for duplicated rows:

df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values:

df.isna().sum()
# Out:
# Unnamed: 0           0
# Customer Id          0
# Age                  0
# Edu                  0
# Years Employed       0
# Income               0
# Card Debt            0
# Other Debt           0
# Defaulted          150
# DebtIncomeRatio      0
# dtype: int64

# %%
# Removal of ineffectual columns:

df.drop(columns = 'Unnamed: 0', inplace =True)

# %%
# Imputation:

df['Defaulted'].fillna(method='ffill', inplace = True)

# %%
# Final Check: 

df.isna().sum()
# Out:
# Customer Id        0
# Age                0
# Edu                0
# Years Employed     0
# Income             0
# Card Debt          0
# Other Debt         0
# Defaulted          0
# DebtIncomeRatio    0
# dtype: int64

# %% [markdown]
# "We will use customer age, education, years of employment, income, debt, whether they defaulted, and their debt to income ratio to group them into segments."

# %%
# New data with selected features:

x = df[['Age', 'Edu', 'Years Employed', 'Income', 'Card Debt', 'Other Debt', 'Defaulted', 'DebtIncomeRatio']]

x.head()
# Out:
#    Age  Edu  Years Employed  Income  Card Debt  Other Debt  Defaulted  \
# 0   41    2               6      19      0.124       1.073        0.0
# 1   47    1              26     100      4.582       8.218        0.0
# 2   33    2              10      57      6.111       5.802        1.0
# 3   29    2               4      19      0.681       0.516        0.0
# 4   47    1              31     253      9.308       8.908        0.0
#
#    DebtIncomeRatio
# 0              6.3
# 1             12.8
# 2             20.9
# 3              6.3
# 4              7.2

# %%
# Scaling the Data

scaler = StandardScaler()

scaled_x = scaler.fit_transform(x)

# %% [markdown]
# ## **Inertia Plot**

# %%
# Create an empty list of interia:

inertia = []

# Loop through k values between 2 and 10:

for k in range(2,14):
  km = KMeans(n_clusters = k)
  km.fit(scaled_x)

# Store inertias in empty list above:
  inertia.append(km.inertia_)

# Visualize Scores:

plt.plot(range(2,14), inertia, marker = '.')
plt.title('Inertia Scores\n', fontsize =20)
plt.xlabel('\nClusters', fontsize = 16);
plt.ylabel('Inertia\n', fontsize = 16);

# %% [markdown]
# ## **Silhouette Plot**

# %%
# Save Silhouette scores for various cluster numbers: 

silho = []

for i in range(2, 14):
  km = KMeans(n_clusters = i)
  km.fit(scaled_x)

# Store inertias in empty list above:
  silho.append(silhouette_score(scaled_x, km.labels_))

# Plot scores:

plt.plot(range(2,14), silho, marker = '.');
plt.xlabel('\nNumber of Clusters');
plt.ylabel('Silhouette Score\n');

# %% [markdown]
# Highest silhouetter score is at n = 2.

# %%
# Instantiate Model:
KM = KMeans(n_clusters= 2, random_state = 42)

# Fit model to Data:
KM.fit(scaled_x)

# Evaluate Score:
ss = silhouette_score(scaled_x, KM.labels_)

print('The Optimal Silhouette Score for our model is: ', ss)
# Out:
# The Optimal Silhouette Score for our model is:  0.3377192956984016

# %%
# Add column to dataframe for cluster label:

df['cluster'] = KM.fit_predict(scaled_x)

df.head()
# Out:
#    Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0            1   41    2               6      19      0.124       1.073
# 1            2   47    1              26     100      4.582       8.218
# 2            3   33    2              10      57      6.111       5.802
# 3            4   29    2               4      19      0.681       0.516
# 4            5   47    1              31     253      9.308       8.908
#
#    Defaulted  DebtIncomeRatio  cluster
# 0        0.0              6.3        0
# 1        0.0             12.8        1
# 2        1.0             20.9        1
# 3        0.0              6.3        0
# 4        0.0              7.2        1

# %% [markdown]
# 2. Make bar graphs of the means of each feature for each cluster that you created in part 1 of the assignment.  For each plot the X axis should be the clusters and the y axis should be the mean values for each feature.
#
#
# 3. Write a description of each cluster, based on the graphs and tables you created.
#
#
# 4. Submit your notebook below.

# %%
df.corr().round(2)
# Out:
#                  Customer Id   Age   Edu  Years Employed  Income  Card Debt  \
# Customer Id             1.00 -0.00 -0.03           -0.04   -0.02       0.00
# Age                    -0.00  1.00  0.01            0.55    0.48       0.28
# Edu                    -0.03  0.01  1.00           -0.15    0.22       0.10
# Years Employed         -0.04  0.55 -0.15            1.00    0.63       0.38
# Income                 -0.02  0.48  0.22            0.63    1.00       0.55
# Card Debt               0.00  0.28  0.10            0.38    0.55       1.00
# Other Debt             -0.01  0.34  0.14            0.41    0.60       0.64
# Defaulted               0.01 -0.14  0.09           -0.23   -0.07       0.20
# DebtIncomeRatio         0.01  0.01  0.01           -0.03   -0.04       0.51
# cluster                -0.03  0.49  0.14            0.58    0.65       0.58
#
#                  Other Debt  Defaulted  DebtIncomeRatio  cluster
# Customer Id           -0.01       0.01             0.01    -0.03
# Age                    0.34      -0.14             0.01     0.49
# Edu                    0.14       0.09             0.01     0.14
# Years Employed         0.41      -0.23            -0.03     0.58
# Income                 0.60      -0.07            -0.04     0.65
# Card Debt              0.64       0.20             0.51     0.58
# Other Debt             1.00       0.10             0.57     0.67
# Defaulted              0.10       1.00             0.31     0.01
# DebtIncomeRatio        0.57       0.31             1.00     0.30
# cluster                0.67       0.01             0.30     1.00

# %%
# Dataframe features grouped by cluster:

clusters = df.groupby('cluster', as_index = False).mean().round(2)

clusters
# Out:
#    cluster  Customer Id    Age   Edu  Years Employed  Income  Card Debt  \
# 0        0       429.56  32.96  1.64             6.5   33.59       0.94
# 1        1       410.72  42.58  1.96            16.1   94.38       3.91
#
#    Other Debt  Defaulted  DebtIncomeRatio
# 0        1.89       0.25             9.12
# 1        7.41       0.27            14.02

# %%
# Plot a few features with cluster as their demarcation:

plt.scatter(x = df['Income'], y = df['Card Debt'], c = df['cluster'], cmap = 'Dark2');
plt.axvline(x=80, color = 'red')
plt.axvline(x=200, color = 'purple', alpha = .9)
plt.plot(range(5,500,100), range(0,25,5), color = 'pink', alpha = .8)
plt.title('Income Ratio vs Credit Card Debt\n', fontsize = 24)
plt.xlabel('\nIncome Ratio', fontsize = 14);
plt.ylabel('Credit Card Debt\n', fontsize = 14);
plt.grid(axis= 'both', color = 'green', alpha = .4)

# %% [markdown]
# ## **Analysis:**
#
# There is a positive correlation between income and credit card debt; as customers earn more there is a tendency to take on more debt. When grouped by income four different APRs / rewards programs could be considered:
#
# 1.   People making below 80,000.00 dollars (red line) with Credit Card Debt (CCD) below 5%.
# 2.   People making below 80,000.00 dollars with CCD above 5%.
# 3.   People who make 80,000.00 to 200,000.00 dollars.
# 4.   People who make above 200,000.00 dollars.

# %%
# Plotting the Clusters:

fig, axes = plt.subplots(3, 3, figsize =(16, 12))

# flatten plot figure to single row array:

axes = axes.ravel()

# Loop over columns and plot each feature separately:

for i, col in enumerate(clusters.columns[1:]):
  axes[i].bar(clusters['cluster'], clusters[col], alpha =.6, color = '#3f007d')
  axes[i].set_title(f'Mean {col}')

# %%
import seaborn as sns

# From Cole who showed me in class:

sns.pairplot(df, hue = 'cluster');

# %% [markdown]
# ## **Graph Analysis:**
#
# Cluster 0:
#
#
# > Cluster 0 has the younger customer base, the lower income (less than half of cluster 1’s income), and a significantly lower credit card debt percentage. As the younger age group, they’ve also been employed for less time and have less ‘Other Debt’.
#
# Cluster 1:
#
# > Cluster One has the higher income, Debt to Income ratio and average debt. This group scores significantly higher in every metric with the exception of defaulted debt and education levels which are relatively close with cluster 0.
